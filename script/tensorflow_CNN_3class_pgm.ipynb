# %%
import os
import random
from PIL import Image
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses, callbacks, regularizers
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ["TF_DETERMINISTIC_OPS"] = "-1"
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.config.experimental.enable_op_determinism()

IMG_HEIGHT = 64
IMG_WIDTH = 64
BATCH_SIZE = 128
num_classes = 3
learning_rate = 1e-4
epoch = 20

# %%
#pgmを使うならこっち
data_dir = "C:/Users/torat/Desktop/sotsuken/sotsuken/images_350_weight_pgm"
unlabeled_dir = "C:/Users/torat/Desktop/sotsuken/sotsuken/unlabeled_dir_weight_pgm"
label_dict = {
    # Mild (0)
    'AF483470.1': 0, 'EF192393.1': 0, 'EF192394.1': 0,
    'EF580923.1': 0, 'EU879915.1': 0, 'EU879916.1': 0,
    'JQ806338.1': 0, 'KF418767.1': 0, 'KR611355.1': 0,
    'KT987925.1': 0, 'LC388852.1': 0, 'LC388854.1': 0,
    'M25199.1': 0, 'MG450357.1': 0, 'Y09575.1': 0,

    # Moderate (1)
    'AF454395.1': 1, 'KF683200.1': 1, 'KJ857496.1': 1,
    'KR611360.1': 1, 'M88678.1': 1, 'X17268.1': 1,
    'GQ853461.1': 1, 'EU879913.1': 1,

    # Severe (2)
    'AJ634596.1': 2, 'AY518939.1': 2, 'AY532801.1': 2,
    'DD220185.1': 2, 'FR851463.1': 2, 'JX280944.1': 2,
    'U23060.1': 2, 'X58388.1': 2, 'X76846.1': 2,
    'X97387.1': 2, 'Y09383.1': 2, 'LC523672.1': 2,
    'LC523675.1': 2, 'LC523676.1': 2
}

# 元のファイル名（拡張子なし）
labeled_bases = list(label_dict.keys())
labels = list(label_dict.values())


filepaths = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith(".pgm")]

# 水増しファイルをオリジナルごとにマッピング
original_to_aug = {}
for orig_base in labeled_bases:
    aug_files = [f for f in os.listdir(data_dir) if f.startswith(orig_base + '_shift') and f.endswith('.pgm')]
    aug_files_sorted = sorted(aug_files, key=lambda x: int(x.split('_shift')[1].split('.')[0]))  # start000からソート
    original_to_aug[orig_base] = [os.path.join(data_dir, f) for f in aug_files_sorted]

# 未ラベルファイル: unlabeled_dirの全ファイル
unlabeled_fullpaths = [os.path.join(unlabeled_dir, f) for f in os.listdir(unlabeled_dir) if f.endswith(".pgm")]

# 水増し数確認（仮定: 各オリジナルあたり350）
aug_count = 350  # 各オリジナルあたりの水増し数（実際の数に合わせて調整）

label_map = {0: "mild", 1: "moderate", 2: "severe"}

print(f"ラベル付きオリジナルの数: {len(labeled_bases)}")
print(f"全ファイル数: {len(filepaths)}")
print(f"未ラベルファイルの数: {len(unlabeled_fullpaths)}")
# Out:
# ラベル付きオリジナルの数: 37
# 全ファイル数: 13276
# 未ラベルファイルの数: 270

# %%
def load_and_preprocess_list(fp_list):
    X = []
    for p in fp_list:
        img = np.array(Image.open(p))
        img = img.reshape(64, 64, 1)
        img = img.astype('float32')
        img /= 255
        X.append(img)
    return np.array(X)

# %%
def make_model():
    model = models.Sequential()
    model.add(layers.Conv2D(16, (3,3), activation='relu', input_shape=(64, 64, 1)))
    model.add(layers.MaxPool2D((2,2)))
    model.add(layers.Conv2D(32, (3,3), activation='relu'))
    model.add(layers.MaxPool2D((2,2)))
    model.add(layers.Conv2D(64, (3,3), activation='relu'))
    model.add(layers.MaxPool2D((2,2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(layers.Dense(num_classes, activation='softmax'))
    return model

# %%
def jackknife_on_files(labeled_bases, labels, unlabeled_paths, epochs, verbose=1):
    n = len(labeled_bases)
    val_accs = []
    val_records = []

    # 元のファイル名（拡張子付き）で予測結果を記録するための辞書
    labeled_pbm = [base + '.pgm' for base in labeled_bases]  # 元の形式に戻す

    for i in range(n):
        print(f"\nFold {i+1}/{n} ")
        orig_base_i = labeled_bases[i]
        # test: start000.pgm
        test_path = original_to_aug[orig_base_i][0]  # ソート済みなので[0]がstart000
        x_test = load_and_preprocess_list([test_path])
        y_test = np.array([labels[i]], dtype=np.int32)

        val_name = orig_base_i + '.pgm'  # 元の形式
        val_true_label = label_map[int(y_test[0])]

        # train_paths: 他のオリジナルの全水増し
        train_paths = []
        train_labels = []
        for j in range(n):
            if j != i:
                train_paths.extend(original_to_aug[labeled_bases[j]])
                train_labels.extend([labels[j]] * len(original_to_aug[labeled_bases[j]]))

        x_train = load_and_preprocess_list(train_paths)
        y_train = np.array(train_labels, dtype=np.int32)

        early_stop = callbacks.EarlyStopping(
            monitor='loss',
            patience=5,
            restore_best_weights=True
        )

        model = make_model()
        model.compile(optimizer=optimizers.Adam(learning_rate),
                      loss=losses.SparseCategoricalCrossentropy(),
                      metrics=['sparse_categorical_accuracy'])

        history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=epochs, verbose=verbose, callbacks=[early_stop])

        pred_history = model.predict(x_test)
        plt.figure(figsize=(10, 6))

        results.append(history.history)
        pred_results.append([val_name, pred_history])

# %%
results = []
pred_results = []
records = []
stopped_epochs = []

jackknife_on_files(labeled_bases, labels, unlabeled_fullpaths, epochs=epoch, verbose=1)

img_ext = os.listdir(data_dir)[0].split('.')[-1] if os.listdir(data_dir) else 'pgm'
lr_str = "{:.0e}".format(learning_rate)
output_dir = f"{num_classes}classes_weight_350_epoch{epoch}_{lr_str}_{img_ext}"
os.makedirs(output_dir, exist_ok=True)

mat_dir = os.path.join(output_dir, "mat")
acc_dir = os.path.join(output_dir, "acc")
fold_loss_dir = os.path.join(output_dir, "fold_loss")

for d in [mat_dir, acc_dir, fold_loss_dir]:
    os.makedirs(d, exist_ok=True)
# Out:
# Fold 1/37
# Epoch 1/20
# C:\Users\torat\Desktop\sotsuken\sotsuken\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1510 - sparse_categorical_accuracy: 0.5465
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8374 - sparse_categorical_accuracy: 0.7123
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6038 - sparse_categorical_accuracy: 0.8194
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4662 - sparse_categorical_accuracy: 0.8783
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3759 - sparse_categorical_accuracy: 0.9199
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3138 - sparse_categorical_accuracy: 0.9438
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2685 - sparse_categorical_accuracy: 0.9606
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2419 - sparse_categorical_accuracy: 0.9699
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2187 - sparse_categorical_accuracy: 0.9762
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2011 - sparse_categorical_accuracy: 0.9813
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1906 - sparse_categorical_accuracy: 0.9831
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1785 - sparse_categorical_accuracy: 0.9878
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1704 - sparse_categorical_accuracy: 0.9886
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1625 - sparse_categorical_accuracy: 0.9905
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1590 - sparse_categorical_accuracy: 0.9903
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1532 - sparse_categorical_accuracy: 0.9918
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1480 - sparse_categorical_accuracy: 0.9916
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1426 - sparse_categorical_accuracy: 0.9926
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1401 - sparse_categorical_accuracy: 0.9930
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1372 - sparse_categorical_accuracy: 0.9937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Fold 2/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1680 - sparse_categorical_accuracy: 0.5274
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8818 - sparse_categorical_accuracy: 0.6853
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6415 - sparse_categorical_accuracy: 0.7975
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4928 - sparse_categorical_accuracy: 0.8642
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3972 - sparse_categorical_accuracy: 0.9070
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3272 - sparse_categorical_accuracy: 0.9373
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2811 - sparse_categorical_accuracy: 0.9529
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2504 - sparse_categorical_accuracy: 0.9636
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2232 - sparse_categorical_accuracy: 0.9710
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2051 - sparse_categorical_accuracy: 0.9770
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1901 - sparse_categorical_accuracy: 0.9823
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1798 - sparse_categorical_accuracy: 0.9841
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1720 - sparse_categorical_accuracy: 0.9865
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1636 - sparse_categorical_accuracy: 0.9890
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1580 - sparse_categorical_accuracy: 0.9885
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1545 - sparse_categorical_accuracy: 0.9893
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1485 - sparse_categorical_accuracy: 0.9906
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1432 - sparse_categorical_accuracy: 0.9915
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1415 - sparse_categorical_accuracy: 0.9917
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1382 - sparse_categorical_accuracy: 0.9923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Fold 3/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1681 - sparse_categorical_accuracy: 0.5434
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8501 - sparse_categorical_accuracy: 0.7190
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5940 - sparse_categorical_accuracy: 0.8258
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4439 - sparse_categorical_accuracy: 0.8947
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.3544 - sparse_categorical_accuracy: 0.9299
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.3029 - sparse_categorical_accuracy: 0.9478
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2617 - sparse_categorical_accuracy: 0.9634
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2326 - sparse_categorical_accuracy: 0.9722
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2129 - sparse_categorical_accuracy: 0.9780
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1976 - sparse_categorical_accuracy: 0.9802
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1860 - sparse_categorical_accuracy: 0.9849
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1766 - sparse_categorical_accuracy: 0.9864
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1703 - sparse_categorical_accuracy: 0.9875
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1618 - sparse_categorical_accuracy: 0.9902
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1555 - sparse_categorical_accuracy: 0.9910
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1529 - sparse_categorical_accuracy: 0.9899
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1474 - sparse_categorical_accuracy: 0.9917
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1440 - sparse_categorical_accuracy: 0.9923
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1386 - sparse_categorical_accuracy: 0.9937
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1358 - sparse_categorical_accuracy: 0.9930
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Fold 4/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1508 - sparse_categorical_accuracy: 0.5353
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8338 - sparse_categorical_accuracy: 0.7179
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6162 - sparse_categorical_accuracy: 0.8199
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4738 - sparse_categorical_accuracy: 0.8816
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3853 - sparse_categorical_accuracy: 0.9147
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3196 - sparse_categorical_accuracy: 0.9445
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2747 - sparse_categorical_accuracy: 0.9577
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2458 - sparse_categorical_accuracy: 0.9671
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2240 - sparse_categorical_accuracy: 0.9739
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2055 - sparse_categorical_accuracy: 0.9789
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1920 - sparse_categorical_accuracy: 0.9816
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1817 - sparse_categorical_accuracy: 0.9835
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1733 - sparse_categorical_accuracy: 0.9861
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1648 - sparse_categorical_accuracy: 0.9893
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1568 - sparse_categorical_accuracy: 0.9901
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1536 - sparse_categorical_accuracy: 0.9904
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1477 - sparse_categorical_accuracy: 0.9923
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1446 - sparse_categorical_accuracy: 0.9921
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1401 - sparse_categorical_accuracy: 0.9933
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1369 - sparse_categorical_accuracy: 0.9926
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Fold 5/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1638 - sparse_categorical_accuracy: 0.5497
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8664 - sparse_categorical_accuracy: 0.7050
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.6350 - sparse_categorical_accuracy: 0.8065
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4876 - sparse_categorical_accuracy: 0.8744
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3881 - sparse_categorical_accuracy: 0.9202
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.3247 - sparse_categorical_accuracy: 0.9432
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2782 - sparse_categorical_accuracy: 0.9619
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2488 - sparse_categorical_accuracy: 0.9693
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2217 - sparse_categorical_accuracy: 0.9766
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2050 - sparse_categorical_accuracy: 0.9815
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1925 - sparse_categorical_accuracy: 0.9834
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1813 - sparse_categorical_accuracy: 0.9870
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1752 - sparse_categorical_accuracy: 0.9877
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1674 - sparse_categorical_accuracy: 0.9895
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1599 - sparse_categorical_accuracy: 0.9895
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1551 - sparse_categorical_accuracy: 0.9901
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1520 - sparse_categorical_accuracy: 0.9916
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1454 - sparse_categorical_accuracy: 0.9914
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1421 - sparse_categorical_accuracy: 0.9929
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1387 - sparse_categorical_accuracy: 0.9921
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Fold 6/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1571 - sparse_categorical_accuracy: 0.5472
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.8530 - sparse_categorical_accuracy: 0.7163
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6034 - sparse_categorical_accuracy: 0.8253
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4569 - sparse_categorical_accuracy: 0.8890
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3644 - sparse_categorical_accuracy: 0.9300
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3012 - sparse_categorical_accuracy: 0.9522
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2639 - sparse_categorical_accuracy: 0.9649
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2368 - sparse_categorical_accuracy: 0.9732
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2157 - sparse_categorical_accuracy: 0.9769
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2019 - sparse_categorical_accuracy: 0.9822
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1892 - sparse_categorical_accuracy: 0.9844
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1819 - sparse_categorical_accuracy: 0.9854
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1711 - sparse_categorical_accuracy: 0.9882
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1670 - sparse_categorical_accuracy: 0.9887
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1609 - sparse_categorical_accuracy: 0.9889
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1547 - sparse_categorical_accuracy: 0.9905
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1514 - sparse_categorical_accuracy: 0.9909
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1460 - sparse_categorical_accuracy: 0.9925
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1429 - sparse_categorical_accuracy: 0.9924
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1377 - sparse_categorical_accuracy: 0.9929
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#
# Fold 7/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1405 - sparse_categorical_accuracy: 0.5649
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8269 - sparse_categorical_accuracy: 0.7204
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6104 - sparse_categorical_accuracy: 0.8133
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4776 - sparse_categorical_accuracy: 0.8716
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3831 - sparse_categorical_accuracy: 0.9145
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3202 - sparse_categorical_accuracy: 0.9391
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2705 - sparse_categorical_accuracy: 0.9594
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2387 - sparse_categorical_accuracy: 0.9693
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2156 - sparse_categorical_accuracy: 0.9755
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1992 - sparse_categorical_accuracy: 0.9791
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1882 - sparse_categorical_accuracy: 0.9829
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1768 - sparse_categorical_accuracy: 0.9843
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1693 - sparse_categorical_accuracy: 0.9867
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1617 - sparse_categorical_accuracy: 0.9885
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1558 - sparse_categorical_accuracy: 0.9891
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1493 - sparse_categorical_accuracy: 0.9899
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1454 - sparse_categorical_accuracy: 0.9911
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1408 - sparse_categorical_accuracy: 0.9916
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1377 - sparse_categorical_accuracy: 0.9916
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1356 - sparse_categorical_accuracy: 0.9918
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Fold 8/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1733 - sparse_categorical_accuracy: 0.5329
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8918 - sparse_categorical_accuracy: 0.6928
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6577 - sparse_categorical_accuracy: 0.8000
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5037 - sparse_categorical_accuracy: 0.8631
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4033 - sparse_categorical_accuracy: 0.9033
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3348 - sparse_categorical_accuracy: 0.9302
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2849 - sparse_categorical_accuracy: 0.9488
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2487 - sparse_categorical_accuracy: 0.9629
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2234 - sparse_categorical_accuracy: 0.9700
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2052 - sparse_categorical_accuracy: 0.9760
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1867 - sparse_categorical_accuracy: 0.9806
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1767 - sparse_categorical_accuracy: 0.9830
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1674 - sparse_categorical_accuracy: 0.9855
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1580 - sparse_categorical_accuracy: 0.9856
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1520 - sparse_categorical_accuracy: 0.9892
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1472 - sparse_categorical_accuracy: 0.9890
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1424 - sparse_categorical_accuracy: 0.9902
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1368 - sparse_categorical_accuracy: 0.9909
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1335 - sparse_categorical_accuracy: 0.9916
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1316 - sparse_categorical_accuracy: 0.9905
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Fold 9/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1880 - sparse_categorical_accuracy: 0.5151
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9154 - sparse_categorical_accuracy: 0.6889
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6617 - sparse_categorical_accuracy: 0.8042
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5004 - sparse_categorical_accuracy: 0.8723
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3885 - sparse_categorical_accuracy: 0.9148
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3180 - sparse_categorical_accuracy: 0.9432
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2697 - sparse_categorical_accuracy: 0.9606
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2422 - sparse_categorical_accuracy: 0.9680
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2183 - sparse_categorical_accuracy: 0.9762
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2042 - sparse_categorical_accuracy: 0.9789
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1887 - sparse_categorical_accuracy: 0.9832
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1779 - sparse_categorical_accuracy: 0.9854
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1699 - sparse_categorical_accuracy: 0.9879
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1666 - sparse_categorical_accuracy: 0.9873
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1607 - sparse_categorical_accuracy: 0.9887
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1530 - sparse_categorical_accuracy: 0.9906
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1484 - sparse_categorical_accuracy: 0.9905
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1436 - sparse_categorical_accuracy: 0.9922
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1423 - sparse_categorical_accuracy: 0.9910
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1379 - sparse_categorical_accuracy: 0.9928
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Fold 10/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1533 - sparse_categorical_accuracy: 0.5466
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8533 - sparse_categorical_accuracy: 0.7127
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6209 - sparse_categorical_accuracy: 0.8140
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4778 - sparse_categorical_accuracy: 0.8738
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3770 - sparse_categorical_accuracy: 0.9165
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3105 - sparse_categorical_accuracy: 0.9436
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2681 - sparse_categorical_accuracy: 0.9581
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2334 - sparse_categorical_accuracy: 0.9690
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2076 - sparse_categorical_accuracy: 0.9763
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1893 - sparse_categorical_accuracy: 0.9809
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1765 - sparse_categorical_accuracy: 0.9858
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1673 - sparse_categorical_accuracy: 0.9862
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1602 - sparse_categorical_accuracy: 0.9871
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1528 - sparse_categorical_accuracy: 0.9889
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1457 - sparse_categorical_accuracy: 0.9909
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1421 - sparse_categorical_accuracy: 0.9910
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1374 - sparse_categorical_accuracy: 0.9920
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1336 - sparse_categorical_accuracy: 0.9917
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1307 - sparse_categorical_accuracy: 0.9922
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1258 - sparse_categorical_accuracy: 0.9928
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Fold 11/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1925 - sparse_categorical_accuracy: 0.5251
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9135 - sparse_categorical_accuracy: 0.6825
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6632 - sparse_categorical_accuracy: 0.7945
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5017 - sparse_categorical_accuracy: 0.8630
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3927 - sparse_categorical_accuracy: 0.9102
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3222 - sparse_categorical_accuracy: 0.9401
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2722 - sparse_categorical_accuracy: 0.9569
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2373 - sparse_categorical_accuracy: 0.9688
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2122 - sparse_categorical_accuracy: 0.9761
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1976 - sparse_categorical_accuracy: 0.9809
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1829 - sparse_categorical_accuracy: 0.9842
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1737 - sparse_categorical_accuracy: 0.9860
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1660 - sparse_categorical_accuracy: 0.9872
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1597 - sparse_categorical_accuracy: 0.9871
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1555 - sparse_categorical_accuracy: 0.9891
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1480 - sparse_categorical_accuracy: 0.9899
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1427 - sparse_categorical_accuracy: 0.9915
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1384 - sparse_categorical_accuracy: 0.9917
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1363 - sparse_categorical_accuracy: 0.9917
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1317 - sparse_categorical_accuracy: 0.9919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Fold 12/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1686 - sparse_categorical_accuracy: 0.5389
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8508 - sparse_categorical_accuracy: 0.7174
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5927 - sparse_categorical_accuracy: 0.8303
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4360 - sparse_categorical_accuracy: 0.8976
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3452 - sparse_categorical_accuracy: 0.9364
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2858 - sparse_categorical_accuracy: 0.9594
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2472 - sparse_categorical_accuracy: 0.9696
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2227 - sparse_categorical_accuracy: 0.9771
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2049 - sparse_categorical_accuracy: 0.9809
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1890 - sparse_categorical_accuracy: 0.9844
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1836 - sparse_categorical_accuracy: 0.9847
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1720 - sparse_categorical_accuracy: 0.9882
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1646 - sparse_categorical_accuracy: 0.9893
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1597 - sparse_categorical_accuracy: 0.9892
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1544 - sparse_categorical_accuracy: 0.9904
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1510 - sparse_categorical_accuracy: 0.9903
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1475 - sparse_categorical_accuracy: 0.9906
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1400 - sparse_categorical_accuracy: 0.9930
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1358 - sparse_categorical_accuracy: 0.9926
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1326 - sparse_categorical_accuracy: 0.9930
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Fold 13/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1384 - sparse_categorical_accuracy: 0.5434
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8229 - sparse_categorical_accuracy: 0.7366
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6016 - sparse_categorical_accuracy: 0.8327
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4654 - sparse_categorical_accuracy: 0.8858
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3691 - sparse_categorical_accuracy: 0.9309
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.9517
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2678 - sparse_categorical_accuracy: 0.9648
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2406 - sparse_categorical_accuracy: 0.9732
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2204 - sparse_categorical_accuracy: 0.9783
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2052 - sparse_categorical_accuracy: 0.9829
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1947 - sparse_categorical_accuracy: 0.9850
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1830 - sparse_categorical_accuracy: 0.9872
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1750 - sparse_categorical_accuracy: 0.9891
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1689 - sparse_categorical_accuracy: 0.9898
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1622 - sparse_categorical_accuracy: 0.9906
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1570 - sparse_categorical_accuracy: 0.9916
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1536 - sparse_categorical_accuracy: 0.9926
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1486 - sparse_categorical_accuracy: 0.9922
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1457 - sparse_categorical_accuracy: 0.9929
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1417 - sparse_categorical_accuracy: 0.9935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Fold 14/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1610 - sparse_categorical_accuracy: 0.5480
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8632 - sparse_categorical_accuracy: 0.7131
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6263 - sparse_categorical_accuracy: 0.8191
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4802 - sparse_categorical_accuracy: 0.8801
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3799 - sparse_categorical_accuracy: 0.9232
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3166 - sparse_categorical_accuracy: 0.9446
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2744 - sparse_categorical_accuracy: 0.9594
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2420 - sparse_categorical_accuracy: 0.9708
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2191 - sparse_categorical_accuracy: 0.9762
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2046 - sparse_categorical_accuracy: 0.9802
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1929 - sparse_categorical_accuracy: 0.9830
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1830 - sparse_categorical_accuracy: 0.9851
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1749 - sparse_categorical_accuracy: 0.9868
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1665 - sparse_categorical_accuracy: 0.9892
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1612 - sparse_categorical_accuracy: 0.9903
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1557 - sparse_categorical_accuracy: 0.9905
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1523 - sparse_categorical_accuracy: 0.9907
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1477 - sparse_categorical_accuracy: 0.9919
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1436 - sparse_categorical_accuracy: 0.9922
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1393 - sparse_categorical_accuracy: 0.9925
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Fold 15/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1649 - sparse_categorical_accuracy: 0.5308
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8667 - sparse_categorical_accuracy: 0.6998
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.6238 - sparse_categorical_accuracy: 0.8063
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4742 - sparse_categorical_accuracy: 0.8722
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3718 - sparse_categorical_accuracy: 0.9189
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3133 - sparse_categorical_accuracy: 0.9426
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2703 - sparse_categorical_accuracy: 0.9556
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2379 - sparse_categorical_accuracy: 0.9658
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2171 - sparse_categorical_accuracy: 0.9724
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1995 - sparse_categorical_accuracy: 0.9767
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1852 - sparse_categorical_accuracy: 0.9824
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1718 - sparse_categorical_accuracy: 0.9849
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1633 - sparse_categorical_accuracy: 0.9872
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1575 - sparse_categorical_accuracy: 0.9889
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1500 - sparse_categorical_accuracy: 0.9904
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1443 - sparse_categorical_accuracy: 0.9908
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1417 - sparse_categorical_accuracy: 0.9913
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1376 - sparse_categorical_accuracy: 0.9902
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1328 - sparse_categorical_accuracy: 0.9929
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1315 - sparse_categorical_accuracy: 0.9919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Fold 16/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1410 - sparse_categorical_accuracy: 0.5634
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8325 - sparse_categorical_accuracy: 0.7268
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5951 - sparse_categorical_accuracy: 0.8274
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4475 - sparse_categorical_accuracy: 0.8940
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3528 - sparse_categorical_accuracy: 0.9320
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2915 - sparse_categorical_accuracy: 0.9566
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2535 - sparse_categorical_accuracy: 0.9677
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2255 - sparse_categorical_accuracy: 0.9752
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2061 - sparse_categorical_accuracy: 0.9806
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1927 - sparse_categorical_accuracy: 0.9834
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1779 - sparse_categorical_accuracy: 0.9867
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1706 - sparse_categorical_accuracy: 0.9876
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1612 - sparse_categorical_accuracy: 0.9901
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1556 - sparse_categorical_accuracy: 0.9903
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1511 - sparse_categorical_accuracy: 0.9909
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1446 - sparse_categorical_accuracy: 0.9927
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1404 - sparse_categorical_accuracy: 0.9925
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1363 - sparse_categorical_accuracy: 0.9928
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1330 - sparse_categorical_accuracy: 0.9933
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1303 - sparse_categorical_accuracy: 0.9939
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Fold 17/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1441 - sparse_categorical_accuracy: 0.5655
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8517 - sparse_categorical_accuracy: 0.7175
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6328 - sparse_categorical_accuracy: 0.8100
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4939 - sparse_categorical_accuracy: 0.8689
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3980 - sparse_categorical_accuracy: 0.9080
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3290 - sparse_categorical_accuracy: 0.9352
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2795 - sparse_categorical_accuracy: 0.9542
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2428 - sparse_categorical_accuracy: 0.9659
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2204 - sparse_categorical_accuracy: 0.9737
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2004 - sparse_categorical_accuracy: 0.9810
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1860 - sparse_categorical_accuracy: 0.9834
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1769 - sparse_categorical_accuracy: 0.9844
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1643 - sparse_categorical_accuracy: 0.9875
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1594 - sparse_categorical_accuracy: 0.9882
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1530 - sparse_categorical_accuracy: 0.9887
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1496 - sparse_categorical_accuracy: 0.9903
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1441 - sparse_categorical_accuracy: 0.9909
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1421 - sparse_categorical_accuracy: 0.9909
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1365 - sparse_categorical_accuracy: 0.9916
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1334 - sparse_categorical_accuracy: 0.9922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Fold 18/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1209 - sparse_categorical_accuracy: 0.5765
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8112 - sparse_categorical_accuracy: 0.7374
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5956 - sparse_categorical_accuracy: 0.8245
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4514 - sparse_categorical_accuracy: 0.8874
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3555 - sparse_categorical_accuracy: 0.9278
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2923 - sparse_categorical_accuracy: 0.9508
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2517 - sparse_categorical_accuracy: 0.9658
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2209 - sparse_categorical_accuracy: 0.9747
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2009 - sparse_categorical_accuracy: 0.9805
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1856 - sparse_categorical_accuracy: 0.9834
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1741 - sparse_categorical_accuracy: 0.9860
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1638 - sparse_categorical_accuracy: 0.9889
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1570 - sparse_categorical_accuracy: 0.9893
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1501 - sparse_categorical_accuracy: 0.9909
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1436 - sparse_categorical_accuracy: 0.9917
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1409 - sparse_categorical_accuracy: 0.9916
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1352 - sparse_categorical_accuracy: 0.9936
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1333 - sparse_categorical_accuracy: 0.9940
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1288 - sparse_categorical_accuracy: 0.9936
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1247 - sparse_categorical_accuracy: 0.9943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Fold 19/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1353 - sparse_categorical_accuracy: 0.5549
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8257 - sparse_categorical_accuracy: 0.7293
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5978 - sparse_categorical_accuracy: 0.8296
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4572 - sparse_categorical_accuracy: 0.8851
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3655 - sparse_categorical_accuracy: 0.9234
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3051 - sparse_categorical_accuracy: 0.9459
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2611 - sparse_categorical_accuracy: 0.9620
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2295 - sparse_categorical_accuracy: 0.9745
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2047 - sparse_categorical_accuracy: 0.9808
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1883 - sparse_categorical_accuracy: 0.9853
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1789 - sparse_categorical_accuracy: 0.9867
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1699 - sparse_categorical_accuracy: 0.9893
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1593 - sparse_categorical_accuracy: 0.9911
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1538 - sparse_categorical_accuracy: 0.9918
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1484 - sparse_categorical_accuracy: 0.9926
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1438 - sparse_categorical_accuracy: 0.9932
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1393 - sparse_categorical_accuracy: 0.9934
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1353 - sparse_categorical_accuracy: 0.9937
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1320 - sparse_categorical_accuracy: 0.9945
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1277 - sparse_categorical_accuracy: 0.9947
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Fold 20/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1767 - sparse_categorical_accuracy: 0.5247
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8855 - sparse_categorical_accuracy: 0.7022
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6460 - sparse_categorical_accuracy: 0.8079
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5058 - sparse_categorical_accuracy: 0.8691
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4089 - sparse_categorical_accuracy: 0.9075
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3423 - sparse_categorical_accuracy: 0.9305
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2951 - sparse_categorical_accuracy: 0.9475
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2620 - sparse_categorical_accuracy: 0.9614
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2346 - sparse_categorical_accuracy: 0.9702
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2148 - sparse_categorical_accuracy: 0.9740
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2007 - sparse_categorical_accuracy: 0.9784
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1878 - sparse_categorical_accuracy: 0.9825
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1774 - sparse_categorical_accuracy: 0.9842
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1702 - sparse_categorical_accuracy: 0.9852
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1644 - sparse_categorical_accuracy: 0.9871
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1588 - sparse_categorical_accuracy: 0.9877
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1547 - sparse_categorical_accuracy: 0.9888
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1480 - sparse_categorical_accuracy: 0.9905
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1451 - sparse_categorical_accuracy: 0.9905
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1405 - sparse_categorical_accuracy: 0.9905
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Fold 21/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1428 - sparse_categorical_accuracy: 0.5541
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8465 - sparse_categorical_accuracy: 0.7233
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6155 - sparse_categorical_accuracy: 0.8192
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4611 - sparse_categorical_accuracy: 0.8835
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3675 - sparse_categorical_accuracy: 0.9227
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3045 - sparse_categorical_accuracy: 0.9466
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2669 - sparse_categorical_accuracy: 0.9591
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2380 - sparse_categorical_accuracy: 0.9690
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2179 - sparse_categorical_accuracy: 0.9769
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2027 - sparse_categorical_accuracy: 0.9799
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1899 - sparse_categorical_accuracy: 0.9845
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1799 - sparse_categorical_accuracy: 0.9858
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1724 - sparse_categorical_accuracy: 0.9870
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1650 - sparse_categorical_accuracy: 0.9894
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1578 - sparse_categorical_accuracy: 0.9906
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1545 - sparse_categorical_accuracy: 0.9905
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1513 - sparse_categorical_accuracy: 0.9906
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1445 - sparse_categorical_accuracy: 0.9926
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1416 - sparse_categorical_accuracy: 0.9918
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1392 - sparse_categorical_accuracy: 0.9926
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Fold 22/37
# C:\Users\torat\AppData\Local\Temp\ipykernel_43132\2579659373.py:45: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 6))
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1586 - sparse_categorical_accuracy: 0.5398
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8872 - sparse_categorical_accuracy: 0.6996
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6462 - sparse_categorical_accuracy: 0.8062
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4949 - sparse_categorical_accuracy: 0.8701
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3905 - sparse_categorical_accuracy: 0.9155
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3200 - sparse_categorical_accuracy: 0.9397
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2685 - sparse_categorical_accuracy: 0.9587
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2361 - sparse_categorical_accuracy: 0.9679
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2106 - sparse_categorical_accuracy: 0.9769
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1945 - sparse_categorical_accuracy: 0.9808
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1827 - sparse_categorical_accuracy: 0.9844
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1706 - sparse_categorical_accuracy: 0.9867
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1638 - sparse_categorical_accuracy: 0.9880
# Epoch 14/20
# ...
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1583 - sparse_categorical_accuracy: 0.9898
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1518 - sparse_categorical_accuracy: 0.9917
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1489 - sparse_categorical_accuracy: 0.9914
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1435 - sparse_categorical_accuracy: 0.9913
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1395 - sparse_categorical_accuracy: 0.9926
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1380 - sparse_categorical_accuracy: 0.9924
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Fold 31/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1997 - sparse_categorical_accuracy: 0.4997
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.9505 - sparse_categorical_accuracy: 0.6556
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.6936 - sparse_categorical_accuracy: 0.7780
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5293 - sparse_categorical_accuracy: 0.8495
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4146 - sparse_categorical_accuracy: 0.8997
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.3409 - sparse_categorical_accuracy: 0.9304
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2891 - sparse_categorical_accuracy: 0.9474
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2519 - sparse_categorical_accuracy: 0.9612
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2264 - sparse_categorical_accuracy: 0.9710
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2040 - sparse_categorical_accuracy: 0.9781
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1913 - sparse_categorical_accuracy: 0.9787
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1799 - sparse_categorical_accuracy: 0.9822
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1696 - sparse_categorical_accuracy: 0.9847
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1601 - sparse_categorical_accuracy: 0.9873
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1568 - sparse_categorical_accuracy: 0.9871
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1505 - sparse_categorical_accuracy: 0.9875
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1434 - sparse_categorical_accuracy: 0.9892
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1389 - sparse_categorical_accuracy: 0.9911
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1356 - sparse_categorical_accuracy: 0.9906
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1320 - sparse_categorical_accuracy: 0.9911
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Fold 32/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1763 - sparse_categorical_accuracy: 0.5284
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8971 - sparse_categorical_accuracy: 0.6862
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.6618 - sparse_categorical_accuracy: 0.7950
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5036 - sparse_categorical_accuracy: 0.8640
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4009 - sparse_categorical_accuracy: 0.9033
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3275 - sparse_categorical_accuracy: 0.9331
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2812 - sparse_categorical_accuracy: 0.9515
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2494 - sparse_categorical_accuracy: 0.9625
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2239 - sparse_categorical_accuracy: 0.9710
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2052 - sparse_categorical_accuracy: 0.9751
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1902 - sparse_categorical_accuracy: 0.9806
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1793 - sparse_categorical_accuracy: 0.9834
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1687 - sparse_categorical_accuracy: 0.9851
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1588 - sparse_categorical_accuracy: 0.9884
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1526 - sparse_categorical_accuracy: 0.9905
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1481 - sparse_categorical_accuracy: 0.9900
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1407 - sparse_categorical_accuracy: 0.9921
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1372 - sparse_categorical_accuracy: 0.9914
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1344 - sparse_categorical_accuracy: 0.9925
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1300 - sparse_categorical_accuracy: 0.9920
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Fold 33/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1296 - sparse_categorical_accuracy: 0.5631
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8412 - sparse_categorical_accuracy: 0.7168
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6201 - sparse_categorical_accuracy: 0.8127
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4825 - sparse_categorical_accuracy: 0.8751
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3886 - sparse_categorical_accuracy: 0.9157
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.3197 - sparse_categorical_accuracy: 0.9427
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2770 - sparse_categorical_accuracy: 0.9592
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2502 - sparse_categorical_accuracy: 0.9657
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2233 - sparse_categorical_accuracy: 0.9746
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2075 - sparse_categorical_accuracy: 0.9804
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1955 - sparse_categorical_accuracy: 0.9822
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1884 - sparse_categorical_accuracy: 0.9835
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1808 - sparse_categorical_accuracy: 0.9851
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1701 - sparse_categorical_accuracy: 0.9882
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1651 - sparse_categorical_accuracy: 0.9885
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1603 - sparse_categorical_accuracy: 0.9892
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1538 - sparse_categorical_accuracy: 0.9906
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1497 - sparse_categorical_accuracy: 0.9918
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1446 - sparse_categorical_accuracy: 0.9917
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1408 - sparse_categorical_accuracy: 0.9931
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Fold 34/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1545 - sparse_categorical_accuracy: 0.5580
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8502 - sparse_categorical_accuracy: 0.7124
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6268 - sparse_categorical_accuracy: 0.8107
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4801 - sparse_categorical_accuracy: 0.8751
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.3853 - sparse_categorical_accuracy: 0.9183
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.3205 - sparse_categorical_accuracy: 0.9430
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2728 - sparse_categorical_accuracy: 0.9633
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2441 - sparse_categorical_accuracy: 0.9704
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2263 - sparse_categorical_accuracy: 0.9755
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2098 - sparse_categorical_accuracy: 0.9806
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2005 - sparse_categorical_accuracy: 0.9810
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1874 - sparse_categorical_accuracy: 0.9851
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1772 - sparse_categorical_accuracy: 0.9863
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1727 - sparse_categorical_accuracy: 0.9882
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1652 - sparse_categorical_accuracy: 0.9899
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1602 - sparse_categorical_accuracy: 0.9888
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1561 - sparse_categorical_accuracy: 0.9900
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1508 - sparse_categorical_accuracy: 0.9919
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1471 - sparse_categorical_accuracy: 0.9919
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1428 - sparse_categorical_accuracy: 0.9918
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Fold 35/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1826 - sparse_categorical_accuracy: 0.5270
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8889 - sparse_categorical_accuracy: 0.6980
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6203 - sparse_categorical_accuracy: 0.8148
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4544 - sparse_categorical_accuracy: 0.8856
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3597 - sparse_categorical_accuracy: 0.9238
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2977 - sparse_categorical_accuracy: 0.9454
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2572 - sparse_categorical_accuracy: 0.9594
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2328 - sparse_categorical_accuracy: 0.9659
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2094 - sparse_categorical_accuracy: 0.9749
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1962 - sparse_categorical_accuracy: 0.9779
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1839 - sparse_categorical_accuracy: 0.9816
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1739 - sparse_categorical_accuracy: 0.9848
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1645 - sparse_categorical_accuracy: 0.9867
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1579 - sparse_categorical_accuracy: 0.9865
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1489 - sparse_categorical_accuracy: 0.9889
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1476 - sparse_categorical_accuracy: 0.9895
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1409 - sparse_categorical_accuracy: 0.9902
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1382 - sparse_categorical_accuracy: 0.9909
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1347 - sparse_categorical_accuracy: 0.9905
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1295 - sparse_categorical_accuracy: 0.9914
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Fold 36/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1724 - sparse_categorical_accuracy: 0.5475
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8808 - sparse_categorical_accuracy: 0.6993
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6211 - sparse_categorical_accuracy: 0.8115
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4761 - sparse_categorical_accuracy: 0.8749
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3826 - sparse_categorical_accuracy: 0.9113
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3198 - sparse_categorical_accuracy: 0.9350
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2752 - sparse_categorical_accuracy: 0.9536
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2423 - sparse_categorical_accuracy: 0.9655
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2213 - sparse_categorical_accuracy: 0.9714
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2024 - sparse_categorical_accuracy: 0.9779
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1872 - sparse_categorical_accuracy: 0.9820
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1763 - sparse_categorical_accuracy: 0.9850
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1675 - sparse_categorical_accuracy: 0.9852
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1630 - sparse_categorical_accuracy: 0.9874
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1552 - sparse_categorical_accuracy: 0.9892
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9902
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1414 - sparse_categorical_accuracy: 0.9923
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1391 - sparse_categorical_accuracy: 0.9919
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1351 - sparse_categorical_accuracy: 0.9930
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1336 - sparse_categorical_accuracy: 0.9916
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Fold 37/37
# Epoch 1/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1557 - sparse_categorical_accuracy: 0.5431
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.8477 - sparse_categorical_accuracy: 0.7098
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.6215 - sparse_categorical_accuracy: 0.8071
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4762 - sparse_categorical_accuracy: 0.8751
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3739 - sparse_categorical_accuracy: 0.9172
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3156 - sparse_categorical_accuracy: 0.9411
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2697 - sparse_categorical_accuracy: 0.9572
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2379 - sparse_categorical_accuracy: 0.9683
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2134 - sparse_categorical_accuracy: 0.9750
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1975 - sparse_categorical_accuracy: 0.9801
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1831 - sparse_categorical_accuracy: 0.9830
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1722 - sparse_categorical_accuracy: 0.9865
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1636 - sparse_categorical_accuracy: 0.9876
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1573 - sparse_categorical_accuracy: 0.9890
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1511 - sparse_categorical_accuracy: 0.9894
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1501 - sparse_categorical_accuracy: 0.9893
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1418 - sparse_categorical_accuracy: 0.9914
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1399 - sparse_categorical_accuracy: 0.9918
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1358 - sparse_categorical_accuracy: 0.9915
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1338 - sparse_categorical_accuracy: 0.9923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
for i, r in enumerate(results):
    plt.figure(figsize=(8, 5))
    plt.plot(r["loss"], label="Train Loss", color="blue")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Fold {i + 1} - Train Loss")
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(fold_loss_dir, f"fold_{i + 1}_loss.png"))
    plt.close()

for i, r in enumerate(results):
    plt.figure(figsize=(8, 5))
    plt.plot(r["sparse_categorical_accuracy"], label="Train Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.ylim([0, 1])
    plt.title(f"Fold {i + 1} - Train Accuracy")
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(acc_dir, f"fold_{i + 1}_accuracy.png"))
    plt.close()

plt.figure(figsize=(8, 5))
for i in range(len(results)):
    plt.plot(results[i]['sparse_categorical_accuracy'], label=f'Fold {i + 1}')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.title("Training Accuracy (All Folds)")
plt.legend(loc='lower right')
plt.grid(True)
plt.savefig(os.path.join(acc_dir, "all_folds_accuracy.png"))
plt.show()
plt.close()

pred_labels = []
true_labels = []
for i in range(len(pred_results)):
    pre = pred_results[i][1].tolist()
    pre = pre[0]
    pred_labels.append(pre.index(max(pre)))
    orig_base = '.'.join(pred_results[i][0].split('.')[:-1])
    true_labels.append(label_dict[orig_base])

fixed_labels = ["mild", "moderate", "severe"]
cm = confusion_matrix(true_labels, pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=fixed_labels)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title("Labeled Confusion Matrix (37 folds)")
plt.savefig(os.path.join(mat_dir, "confusion_matrix.png"))
plt.show()
plt.close()

# %%
label_map = {0: "mild", 1: "moderate", 2: "severe"}

misclassified = []

for i in range(len(pred_results)):
    filename = pred_results[i][0]  # 'AF483470.1.pgm'
    probs = pred_results[i][1][0]
    pred_label = int(np.argmax(probs))
    orig_base = '.'.join(filename.split('.')[:-1])
    true_label = int(label_dict[orig_base])

    if pred_label != true_label:
        misclassified.append({
            "PBM_Name": filename,
            "True_Label": label_map[true_label],
            "Pred_Label": label_map[pred_label],
            "Prob_mild": probs[0],
            "Prob_moderate": probs[1],
            "Prob_severe": probs[2]
        })

df_mis = pd.DataFrame(misclassified)
print("=== 誤分類されたサンプル ===")
print(df_mis)
df_mis.to_csv(os.path.join(output_dir, "misclassified_samples.csv"), index=False)
# Out:
# === 誤分類されたサンプル ===
#           PBM_Name True_Label Pred_Label     Prob_mild  Prob_moderate  \
# 0   AF483470.1.pgm       mild     severe  1.942091e-01   1.252726e-01
# 1   EF192394.1.pgm       mild     severe  3.697122e-02   3.847997e-03
# 2   JQ806338.1.pgm       mild     severe  3.245690e-03   2.501344e-03
# 3     Y09575.1.pgm       mild   moderate  6.238983e-03   9.738461e-01
# 4   AF454395.1.pgm   moderate     severe  3.474103e-06   3.748538e-05
# 5   KF683200.1.pgm   moderate       mild  9.677135e-01   2.045905e-03
# 6   KJ857496.1.pgm   moderate     severe  1.914343e-07   7.907055e-04
# 7   KR611360.1.pgm   moderate       mild  9.997744e-01   2.129752e-04
# 8     X17268.1.pgm   moderate     severe  2.444536e-05   8.822123e-05
# 9   GQ853461.1.pgm   moderate     severe  5.278029e-06   2.307663e-04
# 10  EU879913.1.pgm   moderate     severe  4.212597e-04   2.405026e-03
# 11  AY532801.1.pgm     severe   moderate  3.555199e-06   9.997430e-01
# 12  FR851463.1.pgm     severe       mild  9.999995e-01   1.553798e-07
# 13  JX280944.1.pgm     severe   moderate  1.898495e-02   9.632965e-01
# 14    X76846.1.pgm     severe   moderate  8.950832e-02   8.311911e-01
# 15    Y09383.1.pgm     severe   moderate  2.137208e-03   8.202448e-01
# 16  LC523675.1.pgm     severe   moderate  2.434375e-01   4.979394e-01
# 17  LC523676.1.pgm     severe   moderate  1.723634e-01   8.094061e-01
#
#      Prob_severe
# 0   6.805182e-01
# 1   9.591808e-01
# 2   9.942530e-01
# 3   1.991488e-02
# 4   9.999591e-01
# 5   3.024056e-02
# 6   9.992091e-01
# 7   1.268668e-05
# 8   9.998873e-01
# 9   9.997640e-01
# 10  9.971737e-01
# 11  2.533675e-04
# 12  3.677217e-07
# 13  1.771855e-02
# 14  7.930049e-02
# 15  1.776179e-01
# 16  2.586231e-01
# 17  1.823052e-02

# %%
final_early_stop = callbacks.EarlyStopping(
    monitor='loss',
    patience=5,
    restore_best_weights=True
)

final_model = make_model()
final_model.compile(optimizer=optimizers.Adam(learning_rate),
                    loss=losses.SparseCategoricalCrossentropy(),
                    metrics=['sparse_categorical_accuracy'])

# すべての水増しデータを訓練に使用
all_aug_paths = [path for paths in original_to_aug.values() for path in paths]
x_all = load_and_preprocess_list(all_aug_paths)
y_all = np.repeat(labels, [len(original_to_aug[base]) for base in labeled_bases], axis=0).astype(np.int32)

final_history = final_model.fit(x_all, y_all, batch_size=BATCH_SIZE, epochs=epoch, verbose=1, callbacks=[final_early_stop])

plt.plot(final_history.history["sparse_categorical_accuracy"], label="train_acc")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("final model accuracy")
plt.legend()
plt.savefig(os.path.join(acc_dir, "acc.png"))
plt.show()
plt.close()

final_model.save("jackknife_PSTVd_model.keras")

X_unlabeled = load_and_preprocess_list(unlabeled_fullpaths)

unlabeled_preds = final_model.predict(X_unlabeled)

pred_classes = np.argmax(unlabeled_preds, axis=1)
pred_labels = [label_map[c] for c in pred_classes]

df_pred = pd.DataFrame({
    "PBM_Name": [os.path.basename(fp) for fp in unlabeled_fullpaths],
    "Pred_Sym_Severity": pred_labels
})

csv_name = f"{num_classes}classes_epoch{epoch}_{lr_str}_{img_ext}.csv"
df_pred.to_csv(os.path.join(output_dir, csv_name), index=False)
print("Saved CSV:", csv_name)
print("finish")
# Out:
# C:\Users\torat\Desktop\sotsuken\sotsuken\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1525 - sparse_categorical_accuracy: 0.5539
# Epoch 2/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8408 - sparse_categorical_accuracy: 0.7263
# Epoch 3/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.5972 - sparse_categorical_accuracy: 0.8309
# Epoch 4/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.4570 - sparse_categorical_accuracy: 0.8871
# Epoch 5/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.3606 - sparse_categorical_accuracy: 0.9241
# Epoch 6/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2994 - sparse_categorical_accuracy: 0.9510
# Epoch 7/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2617 - sparse_categorical_accuracy: 0.9634
# Epoch 8/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2345 - sparse_categorical_accuracy: 0.9730
# Epoch 9/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2125 - sparse_categorical_accuracy: 0.9782
# Epoch 10/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1996 - sparse_categorical_accuracy: 0.9804
# Epoch 11/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1890 - sparse_categorical_accuracy: 0.9835
# Epoch 12/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1771 - sparse_categorical_accuracy: 0.9876
# Epoch 13/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1703 - sparse_categorical_accuracy: 0.9881
# Epoch 14/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1639 - sparse_categorical_accuracy: 0.9891
# Epoch 15/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1571 - sparse_categorical_accuracy: 0.9905
# Epoch 16/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1527 - sparse_categorical_accuracy: 0.9912
# Epoch 17/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1479 - sparse_categorical_accuracy: 0.9920
# Epoch 18/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1450 - sparse_categorical_accuracy: 0.9912
# Epoch 19/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1380 - sparse_categorical_accuracy: 0.9929
# Epoch 20/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1357 - sparse_categorical_accuracy: 0.9931
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Saved CSV: 3classes_epoch20_1e-04_pgm.csv
# finish
